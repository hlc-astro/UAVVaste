# %%
# Mount/connect my google drive
from google.colab import drive
drive.mount('/content/drive')

path_to_images = '/content/drive/MyDrive/Data/UAVVaste/images/'
#jpg_image_names = sorted([(path_to_images + filename) for filename in os.listdir(path_to_images) if filename.endswith(".jpg")])

##change path
path_to_masks = '/content/drive/MyDrive/Data/UAVVaste/masks/pixel_masks_rgb/'
#npz_mask_names = sorted([(path_to_npz_mask + filename) for filename in os.listdir(path_to_npz_mask) if filename.endswith(".npz")])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install segment-anything
! pip install git+https://github.com/facebookresearch/segment-anything.git &> /dev/null
#! wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth &> /dev/null
! wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth &> /dev/null

#model_type = 'vit_b'
#checkpoint = './sam_vit_b_01ec64.pth'

model_type = 'vit_h'
checkpoint = './sam_vit_h_4b8939.pth'

# %%
from segment_anything import SamPredictor, sam_model_registry
from torch.utils.data import DataLoader
from torchvision import transforms
from PIL import Image
import torch
import os
import sys

# Loading the model
#sam = sam_model_registry[model_type](checkpoint=checkpoint)
#predictor = SamPredictor(sam)
sam_model = sam_model_registry[model_type](checkpoint=checkpoint)

# Define dataset with masks
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, mask_dir, transform=None):
        self.root_dir = root_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(self.root_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir, self.images[idx])
        mask_name = os.path.join(self.mask_dir, self.images[idx])

        image = Image.open(img_name)
        mask = Image.open(mask_name)

        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask




# Define transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)), # Resize to the size a model expects
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Normalization values for pre-trained PyTorch models
])

# Load custom dataset
dataset = CustomDataset(root_dir=path_to_images, mask_dir=path_to_masks, transform=transform)

# Create a DataLoader
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# Fine-tuning the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#predictor.sam.to(device)
#predictor.sam.train()
#predictor.to(device)
#predictor.train()
sam_model.to(device)
sam_model.train();

# Define loss function and optimizer
criterion = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(sam_model.parameters(), lr=0.001, momentum=0.9)

for epoch in range(2):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(dataloader, 0):
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        #outputs = predictor.sam(inputs)
        outputs = sam_model(inputs, multimask_output=None)

        #outputs = sam_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-f379cf53c4ae> in <cell line: 100>()
#     108
#     109         #outputs = predictor.sam(inputs)
# --> 110         outputs = sam_model(inputs, multimask_output=None)
#     111
#     112         #outputs = sam_model(inputs)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/modeling/sam.py in forward(self, batched_input, multimask_output)
#      95                 to subsequent iterations of prediction.
#      96         """
# ---> 97         input_images = torch.stack([self.preprocess(x["image"]) for x in batched_input], dim=0)
#      98         image_embeddings = self.image_encoder(input_images)
#      99
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/modeling/sam.py in <listcomp>(.0)
#      95                 to subsequent iterations of prediction.
#      96         """
# ---> 97         input_images = torch.stack([self.preprocess(x["image"]) for x in batched_input], dim=0)
#      98         image_embeddings = self.image_encoder(input_images)
#      99
#
# IndexError: too many indices for tensor of dimension 3

# %%
from PIL import Image
import os

image_dir = '/content/drive/MyDrive/Data/UAVVaste/images/'
mask_dir = '/content/drive/MyDrive/Data/UAVVaste/masks/pixel_masks_rgb/'

image_files = os.listdir(image_dir)
mask_files = os.listdir(mask_dir)

for image_file, mask_file in zip(image_files, mask_files):
    image_path = os.path.join(image_dir, image_file)
    mask_path = os.path.join(mask_dir, mask_file)

    image = Image.open(image_path)
    mask = Image.open(mask_path)

    image_width, image_height = image.size
    mask_width, mask_height = mask.size

    if image_width != mask_width or image_height != mask_height:
        print(f"Image: {image_file} - Dimensions: {image_width} x {image_height}")
        print(f"Mask: {mask_file} - Dimensions: {mask_width} x {mask_height}")
        print("Image and mask dimensions do not match.")
    else:
        print(f"Image: {image_file} - Dimensions: {image_width} x {image_height}")
        print(f"Mask: {mask_file} - Dimensions: {mask_width} x {mask_height}")
        print("Image and mask dimensions match.")

    image_dtype = image.getbands()[0]
    mask_dtype = mask.getbands()[0]

    if image_dtype != mask_dtype:
        print(f"Image: {image_file} - Data Type: {image_dtype}")
        print(f"Mask: {mask_file} - Data Type: {mask_dtype}")
        print("Image and mask data types do not match.")
    else:
        print(f"Image: {image_file} - Data Type: {image_dtype}")
        print(f"Mask: {mask_file} - Data Type: {mask_dtype}")
        print("Image and mask data types match.")
# Out:
# Image: BATCH_d07_img_6400.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2380.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6400.jpg - Data Type: R
# Mask: BATCH_d07_img_2380.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_580.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_580.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_580.jpg - Data Type: R
# Mask: BATCH_d07_img_580.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1250.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_880.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1250.jpg - Data Type: R
# Mask: BATCH_d07_img_880.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2760.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4550.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2760.jpg - Data Type: R
# Mask: BATCH_d07_img_4550.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_5110.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_6400.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_5110.jpg - Data Type: R
# Mask: BATCH_d07_img_6400.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_450.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_450.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_450.jpg - Data Type: R
# Mask: BATCH_d07_img_450.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2930.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_6970.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2930.jpg - Data Type: R
# Mask: BATCH_d07_img_6970.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_7260.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5110.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_7260.jpg - Data Type: R
# Mask: BATCH_d07_img_5110.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4370.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_6030.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4370.jpg - Data Type: R
# Mask: BATCH_d07_img_6030.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1390.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2760.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1390.jpg - Data Type: R
# Mask: BATCH_d07_img_2760.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4670.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_410.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4670.jpg - Data Type: R
# Mask: BATCH_d07_img_410.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1120.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_3470.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1120.jpg - Data Type: R
# Mask: BATCH_d07_img_3470.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2670.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_1250.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2670.jpg - Data Type: R
# Mask: BATCH_d07_img_1250.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2500.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4730.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2500.jpg - Data Type: R
# Mask: BATCH_d07_img_4730.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2820.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2340.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2820.jpg - Data Type: R
# Mask: BATCH_d07_img_2340.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_3330.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_1760.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_3330.jpg - Data Type: R
# Mask: BATCH_d07_img_1760.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_3010.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4370.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_3010.jpg - Data Type: R
# Mask: BATCH_d07_img_4370.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_650.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_610.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_650.jpg - Data Type: R
# Mask: BATCH_d07_img_610.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_6110.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2930.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6110.jpg - Data Type: R
# Mask: BATCH_d07_img_2930.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_5020.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_7260.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_5020.jpg - Data Type: R
# Mask: BATCH_d07_img_7260.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_5380.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2080.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_5380.jpg - Data Type: R
# Mask: BATCH_d07_img_2080.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4880.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4670.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4880.jpg - Data Type: R
# Mask: BATCH_d07_img_4670.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_5780.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_6520.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_5780.jpg - Data Type: R
# Mask: BATCH_d07_img_6520.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_3860.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_510.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_3860.jpg - Data Type: R
# Mask: BATCH_d07_img_510.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_5960.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_1120.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_5960.jpg - Data Type: R
# Mask: BATCH_d07_img_1120.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_320.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_600.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_320.jpg - Data Type: R
# Mask: BATCH_d07_img_600.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1450.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_1700.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1450.jpg - Data Type: R
# Mask: BATCH_d07_img_1700.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2310.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_360.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2310.jpg - Data Type: R
# Mask: BATCH_d07_img_360.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_3380.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_1390.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_3380.jpg - Data Type: R
# Mask: BATCH_d07_img_1390.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_3170.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2820.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_3170.jpg - Data Type: R
# Mask: BATCH_d07_img_2820.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_460.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_3010.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_460.jpg - Data Type: R
# Mask: BATCH_d07_img_3010.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_6200.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2500.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6200.jpg - Data Type: R
# Mask: BATCH_d07_img_2500.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4610.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2670.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4610.jpg - Data Type: R
# Mask: BATCH_d07_img_2670.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_810.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_650.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_810.jpg - Data Type: R
# Mask: BATCH_d07_img_650.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2270.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_3330.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2270.jpg - Data Type: R
# Mask: BATCH_d07_img_3330.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4920.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_6230.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4920.jpg - Data Type: R
# Mask: BATCH_d07_img_6230.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1550.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_6110.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1550.jpg - Data Type: R
# Mask: BATCH_d07_img_6110.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1650.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5380.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1650.jpg - Data Type: R
# Mask: BATCH_d07_img_5380.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_5900.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_1010.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_5900.jpg - Data Type: R
# Mask: BATCH_d07_img_1010.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1610.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4880.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1610.jpg - Data Type: R
# Mask: BATCH_d07_img_4880.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_6020.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4430.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6020.jpg - Data Type: R
# Mask: BATCH_d07_img_4430.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_6800.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5020.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6800.jpg - Data Type: R
# Mask: BATCH_d07_img_5020.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1160.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_2220.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1160.jpg - Data Type: R
# Mask: BATCH_d07_img_2220.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_6160.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_3860.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6160.jpg - Data Type: R
# Mask: BATCH_d07_img_3860.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4760.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4720.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4760.jpg - Data Type: R
# Mask: BATCH_d07_img_4720.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_7030.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5400.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_7030.jpg - Data Type: R
# Mask: BATCH_d07_img_5400.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4310.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_3270.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4310.jpg - Data Type: R
# Mask: BATCH_d07_img_3270.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_6360.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5960.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6360.jpg - Data Type: R
# Mask: BATCH_d07_img_5960.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_4970.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5780.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_4970.jpg - Data Type: R
# Mask: BATCH_d07_img_5780.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2600.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5210.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2600.jpg - Data Type: R
# Mask: BATCH_d07_img_5210.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_6940.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_320.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_6940.jpg - Data Type: R
# Mask: BATCH_d07_img_320.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_3990.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_1450.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_3990.jpg - Data Type: R
# Mask: BATCH_d07_img_1450.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2720.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_5470.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2720.jpg - Data Type: R
# Mask: BATCH_d07_img_5470.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_2520.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_3380.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_2520.jpg - Data Type: R
# Mask: BATCH_d07_img_3380.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_1330.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_4480.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_1330.jpg - Data Type: R
# Mask: BATCH_d07_img_4480.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_d07_img_720.jpg - Dimensions: 3840 x 2160
# Mask: BATCH_d07_img_6200.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions match.
# Image: BATCH_d07_img_720.jpg - Data Type: R
# Mask: BATCH_d07_img_6200.jpg - Data Type: R
# Image and mask data types match.
# Image: GOPR0032.JPG - Dimensions: 4000 x 3000
# Mask: BATCH_d07_img_5980.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions do not match.
# Image: GOPR0032.JPG - Data Type: R
# Mask: BATCH_d07_img_5980.jpg - Data Type: R
# Image and mask data types match.
# Image: GOPR0040.JPG - Dimensions: 4000 x 3000
# Mask: BATCH_d07_img_2310.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions do not match.
# Image: GOPR0040.JPG - Data Type: R
# Mask: BATCH_d07_img_2310.jpg - Data Type: R
# Image and mask data types match.
# Image: BATCH_s05_img_1260.jpg - Dimensions: 3668 x 1628
# Mask: BATCH_d07_img_3170.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions do not match.
# Image: BATCH_s05_img_1260.jpg - Data Type: R
# Mask: BATCH_d07_img_3170.jpg - Data Type: R
# Image and mask data types match.
# Image: camera_img_1.jpg - Dimensions: 4032 x 3024
# Mask: BATCH_d07_img_1830.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions do not match.
# Image: camera_img_1.jpg - Data Type: R
# Mask: BATCH_d07_img_1830.jpg - Data Type: R
# Image and mask data types match.
# Image: GOPR0035.JPG - Dimensions: 4000 x 3000
# Mask: BATCH_d07_img_6320.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions do not match.
# Image: GOPR0035.JPG - Data Type: R
# Mask: BATCH_d07_img_6320.jpg - Data Type: R
# Image and mask data types match.
# Image: GOPR0030.JPG - Dimensions: 4000 x 3000
# Mask: BATCH_d07_img_4610.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions do not match.
# Image: GOPR0030.JPG - Data Type: R
# Mask: BATCH_d07_img_4610.jpg - Data Type: R
# Image and mask data types match.
# Image: camera_img_3.jpg - Dimensions: 4032 x 3024
# Mask: BATCH_d07_img_460.jpg - Dimensions: 3840 x 2160
# Image and mask dimensions do not match.
# Image: camera_img_3.jpg - Data Type: R
# Mask: BATCH_d07_img_460.jpg - Data Type: R
# Image and mask data types match.
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-3-e5d4f3372b61> in <cell line: 10>()
#      12     mask_path = os.path.join(mask_dir, mask_file)
#      13
# ---> 14     image = Image.open(image_path)
#      15     mask = Image.open(mask_path)
#      16
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3028     for message in accept_warnings:
#    3029         warnings.warn(message)
# -> 3030     raise UnidentifiedImageError(
#    3031         "cannot identify image file %r" % (filename if filename else fp)
#    3032     )
#
# UnidentifiedImageError: cannot identify image file '/content/drive/MyDrive/Data/UAVVaste/images/GOPR0048.JPG'
